# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import scipy.fftpack
from matplotlib import cm
from matplotlib.ticker import FuncFormatter, MultipleLocator, LinearLocator, FormatStrFormatter
import scipy.fftpack
from scipy.io.wavfile import write
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset

# %%
N = 80000
t = np.arange(0,1,1/41000)
T = 2*np.pi
f1=180
f2=188
fs= 41000

# %%
y=  np.sin(f2*t*T)
y2 = np.sin(f2*T*t)
y3 =  np.sin(f1*t*T) +np.sin(f2*T*t)

# %%
for i in range(10):
    z=np.append(z,np.concatenate((np.copy(y),y))) #langes Zeitsignal
#for i in range(1000):
 #   y = np.append(y,0)
write('188Hz.wav', fs, w7)

# %%
T = 2*np.pi

# %%
Nf = 40000
k = np.linspace(0,40000,Nf)

# %%
fy=np.fft.fft(y3)

# %%
fig, ax2 = plt.subplots()
ax2.plot(k[178:Nf-39809],np.abs(fy[178:N-79809]))
plt.show()

# %%
fig, ax = plt.subplots(2,2)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.4, hspace=1)

ax[0][0].plot(t,y)
ax[0][0].axins = zoomed_inset_axes(ax[0][0], 1, loc=1)

ax[0][0].axins.set_xlim(0.1, 0.2)
ax[0][0].axins.set_ylim(-1, 1)
ax[0][0].axins.plot(t*7, y)
ax[0][0].axins.xaxis.set_visible('False')
ax[0][0].axins.yaxis.set_visible('False')
mark_inset(ax[0][0],axins, loc1=1, loc2=4, fc="none", ec="0.5")

plt.yticks(visible=False)
plt.xticks(visible=False)
ax[0][0].set_xlim([0,2*np.pi/30])
ax[0][0].set(xlabel='Zeit [t]', ylabel='Amplitude (V)',title='Sinuston-180Hz')

ax[0][1].plot(t,y2)
ax[0][1].set_xlim([0,2*np.pi/30])
ax[0][1].set(xlabel='Zeit [t]' ,title='Sinuston-188Hz')

ax[1][0].plot(t,y3)
ax[1][0].set_xlim([0,2*np.pi/30])
ax[1][0].set(xlabel='Zeit [t]' ,ylabel='Amplitude (V)',title='Schwebung-180Hz u. 188Hz')


ax[1][1].plot(k[178:Nf-39809],np.abs(fy[178:N-79809]))
ax[1][1].set(xlabel='[Hz]',ylabel='Magnitude', title='Frequenz-Spektrum Schwebung')
ax[1][1].get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x/20000), ',')))



#fig.savefig("Schwebung.png", dpi=300)

plt.show()

# %% [markdown]
# print(y)
